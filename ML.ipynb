# %% [markdown]
# <a href="https://colab.research.google.com/github/manthanrana01/Python/blob/main/ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('House_Data_Large.csv')
x =df[["Sqft","Bedrooms","Bathrooms","YearBuilt","LocationCode"]]
y =df["Price"]
print(x)
# Out:
#      Sqft  Bedrooms  Bathrooms  YearBuilt  LocationCode
# 0    3774         2          4       2006             1
# 1    1460         4          4       1981             3
# 2    1894         2          3       2020             1
# 3    1730         5          4       1992             4
# 4    1695         5          1       1988             5
# ..    ...       ...        ...        ...           ...
# 995  2569         2          1       2015             2
# 996   660         4          4       2010             4
# 997  3281         1          2       1981             5
# 998  3722         1          3       1995             3
# 999  1628         5          3       1988             5
#
# [1000 rows x 5 columns]

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
#from sklearn.linear_model import LogisticRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
df = pd.read_csv("/content/House_Data_Large.csv")

# %%
df.head()
# Out:
#    Sqft  Bedrooms  Bathrooms  YearBuilt  LocationCode       Price
# 0  3774         2          4       2006             1  1279483.77
# 1  1460         4          4       1981             3   748298.12
# 2  1894         2          3       2020             1   768986.29
# 3  1730         5          4       1992             4   871720.14
# 4  1695         5          1       1988             5   834730.66

# %%
x = df[["Sqft","Bedrooms","Bathrooms","YearBuilt","LocationCode"]]
y = df["Price"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
import warnings
warnings.filterwarnings('ignore')
y_pred = model.predict(x_test)
user_input = np.array([[1460,4,4,1981,3]])
predict_price = model.predict(user_input)
print(int(predict_price))
# Out:
# 745272

# %%
y_test
# Out:
# 521    1
# 737    1
# 740    1
# 660    1
# 411    1
#       ..
# 408    0
# 332    1
# 208    1
# 613    0
# 78     1
# Name: pass, Length: 200, dtype: int64

# %%
rmse =  np.sqrt(mean_squared_error(y_test,y_pred))
r2 = r2_score(y_test,y_pred)

# %%
print(r2)
# Out:
# 0.9888245851717383

# %%
df = pd.read_csv("/content/students.csv")

# %%
df
# Out:
#      study_hours  sleep_hours  pass
# 0           6.99         9.10     1
# 1           5.72         8.39     1
# 2           7.30         7.09     1
# 3           9.05         6.03     1
# 4           5.53         8.05     0
# ..           ...          ...   ...
# 995         5.44         8.61     1
# 996         9.60         6.96     1
# 997         7.28         5.68     1
# 998         4.86         6.76     0
# 999         7.15         5.88     1
#
# [1000 rows x 3 columns]

# %%
df.head()#1st five  comes
# Out:
#    study_hours  sleep_hours  pass
# 0         6.99         9.10     1
# 1         5.72         8.39     1
# 2         7.30         7.09     1
# 3         9.05         6.03     1
# 4         5.53         8.05     0

# %%
x = df[["study_hours","sleep_hours"]]
y = df["pass"]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state=42)
model = LogisticRegression()
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
4# Predict on test data
y_pred = model.predict(x_test)

# Take user input
study_hour = int(input("Enter your study hours: "))
sleeping_hours = int(input("Enter your sleeping hours: "))

# --- Input Validation ---
if study_hour < 0 or sleeping_hours < 0:
    print("Invalid input: Hours cannot be negative.")

elif study_hour > 20 or sleeping_hours > 20:
    print("Invalid input: Study or sleeping hours cannot be more than 20.")

elif study_hour + sleeping_hours > 24:
    print("Invalid input: Total hours cannot exceed 24 in a day.")

else:
    # Prepare input for prediction
    user_info = [[study_hour, sleeping_hours]]
    predict_result = model.predict(user_info)

    # Logic based on sleeping hours and model prediction
    if sleeping_hours > 10:
        if predict_result[0] == 1:
            print("You are likely to pass.")
        else:
            print("You need improvement to pass.")
    else:
        print("You need to reduce sleeping hours and increase study hours "
              "to improve your academic performance.")
# Out:
# Enter your study hours: 4
# Enter your sleeping hours: 4
# You need to reduce sleeping hours and increase study hours to improve your academic performance.
