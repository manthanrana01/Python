# %% [markdown]
# <a href="https://colab.research.google.com/github/manthanrana01/Python/blob/main/ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('House_Data_Large.csv')
x =df[["Sqft","Bedrooms","Bathrooms","YearBuilt","LocationCode"]]
y =df["Price"]
print(x)
# Out:
#      Sqft  Bedrooms  Bathrooms  YearBuilt  LocationCode
# 0    3774         2          4       2006             1
# 1    1460         4          4       1981             3
# 2    1894         2          3       2020             1
# 3    1730         5          4       1992             4
# 4    1695         5          1       1988             5
# ..    ...       ...        ...        ...           ...
# 995  2569         2          1       2015             2
# 996   660         4          4       2010             4
# 997  3281         1          2       1981             5
# 998  3722         1          3       1995             3
# 999  1628         5          3       1988             5
#
# [1000 rows x 5 columns]
